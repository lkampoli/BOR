# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
import os
import subprocess
import signal
import scipy.integrate
from scipy.interpolate import interp1d
import sys

# %%
# !pwd
# Out:
# /home/unimelb.edu.au/lcampoli/UoM/Testcases/BOR/TESTCASES/0.BASELINE/DATA

# %%
# !ls
# Out:
# BoR_Data	cfd.dat		       inlet.U.dat	 profiles.ipynb
# BoR_Data.tgz	cfd_sst_exp_inlet.dat  kinlet02.p	 trash
# BoR_SST		epsinlet02.p	       Midbody.zip	 U_Exp.dat
# BoR_SST.tar.gz	inlet.dat	       of.profileU	 uinlet02.p
# Bow.zip		inlet.tgz	       plot_geometry.py

# %%
# Low velocity profiles extracted from the boundaryData in OF
BC_low_wedge0     = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/points_wedge0.txt')
BC_low_wedge1     = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/points_wedge1.txt')
BC_low_symmetry   = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/points_symmetry.txt')

BC_low_U_wedge0   = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/0/U_wedge0.txt')
BC_low_U_wedge1   = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/0/U_wedge1.txt')
BC_low_U_symmetry = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/0/U_symmetry.txt')

BC_low_k_wedge0   = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/0/k_wedge0.txt')
BC_low_k_wedge1   = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/0/k_wedge1.txt')
BC_low_k_symmetry = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/0/k_symmetry.txt')

BC_low_omega_wedge0   = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/0/omega_wedge0.txt')
BC_low_omega_wedge1   = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/0/omega_wedge1.txt')
BC_low_omega_symmetry = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/0/omega_symmetry.txt')

BC_low_nut_wedge0   = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/0/nut_wedge0.txt')
BC_low_nut_wedge1   = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/0/nut_wedge1.txt')
BC_low_nut_symmetry = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.low/inlet/0/nut_symmetry.txt')

## Interpolate low velocity profiles extracted from the boundaryData in OF
g_BC_low_wedge0   = interp1d(BC_low_wedge0[:,1],   BC_low_U_wedge0[:,0])   # y, U
g_BC_low_wedge1   = interp1d(BC_low_wedge1[:,1],   BC_low_U_wedge1[:,0])   # y, U
g_BC_low_symmetry = interp1d(BC_low_symmetry[:,1], BC_low_U_symmetry[:,0]) # y, U

# %%
# High velocity profiles extracted from the boundaryData in OF
BC_high_wedge0     = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.high/inlet/points_wedge0.txt')
BC_high_wedge1     = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.high/inlet/points_wedge1.txt')
BC_high_symmetry   = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.high/inlet/points_symmetry.txt')

BC_high_U_wedge0   = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.high/inlet/0/U_wedge0.txt')
BC_high_U_wedge1   = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.high/inlet/0/U_wedge1.txt')
BC_high_U_symmetry = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.high/inlet/0/U_symmetry.txt')

## Interpolate high velocity profiles extracted from the boundaryData in OF
g_BC_high_wedge0   = interp1d(BC_high_wedge0[:,1],   BC_high_U_wedge0[:,0])   # y, U
g_BC_high_wedge1   = interp1d(BC_high_wedge1[:,1],   BC_high_U_wedge1[:,0])   # y, U
g_BC_high_symmetry = interp1d(BC_high_symmetry[:,1], BC_high_U_symmetry[:,0]) # y, U

# %%
plt.scatter(BC_low_wedge1[:,1], BC_low_U_wedge0[:,0])
plt.scatter(inlet_dat[:,0]*2, inlet_dat[:,1])
plt.plot(BC_low_wedge1[:,1], BC_low_U_wedge0_interpolated_g_inlet_dat_x2, c='k')
plt.scatter(BC_low_wedge1[:,1], BC_low_U_wedge0_interpolated_g_uinlet02_p_x2)
plt.show()
plt.close()

# %%
plt.scatter(BC_low_wedge1[:,1], BC_low_k_wedge0)
plt.scatter(inlet_dat[:,0]*2, inlet_dat[:,2])
plt.plot(BC_low_wedge1[:,1], BC_low_k_wedge0_interpolated_g_inlet_dat_x2, c='k')
plt.scatter(BC_low_wedge1[:,1], BC_low_k_wedge0_interpolated_g_kinlet02_p_x2)
plt.show()
plt.close()

# %%
plt.scatter(BC_low_wedge1[:,1], BC_low_omega_wedge0)
plt.scatter(inlet_dat[:,0]*2, inlet_dat[:,3])
plt.plot(BC_low_wedge1[:,1], BC_low_omega_wedge0_interpolated_g_inlet_dat_x2, c='k')
plt.scatter(BC_low_wedge1[:,1], BC_low_omega_wedge0_interpolated_g_omegainlet02_p_x2)
plt.show()
plt.close()

# %%
plt.scatter(BC_low_wedge1[:,1], BC_low_nut_wedge0, c='b')
plt.scatter(inlet_dat[:,0]*2, inlet_dat[:,2]/inlet_dat[:,3], c='r')
plt.plot(BC_low_wedge1[:,1], BC_low_nut_wedge0_interpolated_g_inlet_dat_x2, c='k')
plt.scatter(BC_low_wedge1[:,1], BC_low_nut_wedge0_interpolated_g_nutinlet02_p_x2, c='y')
plt.show()
plt.close()

# %% [markdown]
# ### inlet.dat

# %%
# y,U,k,omega,u'u',u'v',v'v',w'w'
inlet_dat = np.loadtxt('inlet.dat')

# %%
# interpolate inlet.dat profiles
g_inlet_dat    = interp1d(inlet_dat[:,0], inlet_dat[:,1]) # y, U
g_inlet_dat_x2 = interp1d(inlet_dat[:,0]*2, inlet_dat[:,1]) # y(x2), U

g_inlet_dat_k    = interp1d(inlet_dat[:,0], inlet_dat[:,2]) # y, k
g_inlet_dat_x2_k = interp1d(inlet_dat[:,0]*2, inlet_dat[:,2]) # y(x2), k

g_inlet_dat_omega    = interp1d(inlet_dat[:,0], inlet_dat[:,3]) # y, omega
g_inlet_dat_x2_omega = interp1d(inlet_dat[:,0]*2, inlet_dat[:,3]) # y(x2), omega

# %%
### Interpolate low velocity profiles on inlet.dat data
BC_low_U_wedge0_interpolated_g_inlet_dat_x2   = g_inlet_dat_x2(BC_low_wedge0[:,1])
BC_low_U_wedge1_interpolated_g_inlet_dat_x2   = g_inlet_dat_x2(BC_low_wedge1[:,1])
BC_low_U_symmetry_interpolated_g_inlet_dat_x2 = g_inlet_dat_x2(BC_low_symmetry[:,1])

BC_low_k_wedge0_interpolated_g_inlet_dat_x2   = g_inlet_dat_x2_k(BC_low_wedge0[:,1])
BC_low_k_wedge1_interpolated_g_inlet_dat_x2   = g_inlet_dat_x2_k(BC_low_wedge1[:,1])
BC_low_k_symmetry_interpolated_g_inlet_dat_x2 = g_inlet_dat_x2_k(BC_low_symmetry[:,1])

BC_low_omega_wedge0_interpolated_g_inlet_dat_x2   = g_inlet_dat_x2_omega(BC_low_wedge0[:,1])
BC_low_omega_wedge1_interpolated_g_inlet_dat_x2   = g_inlet_dat_x2_omega(BC_low_wedge1[:,1])
BC_low_omega_symmetry_interpolated_g_inlet_dat_x2 = g_inlet_dat_x2_omega(BC_low_symmetry[:,1])

BC_low_nut_wedge0_interpolated_g_inlet_dat_x2   = BC_low_k_wedge0_interpolated_g_inlet_dat_x2 / BC_low_omega_wedge0_interpolated_g_inlet_dat_x2
BC_low_nut_wedge1_interpolated_g_inlet_dat_x2   = BC_low_k_wedge1_interpolated_g_inlet_dat_x2 / BC_low_omega_wedge1_interpolated_g_inlet_dat_x2
BC_low_nut_symmetry_interpolated_g_inlet_dat_x2 = BC_low_k_symmetry_interpolated_g_inlet_dat_x2 / BC_low_omega_symmetry_interpolated_g_inlet_dat_x2

# %%
### Interpolate high velocity profiles on inlet.dat data
BC_high_U_wedge0_interpolated_g_inlet_dat_x2   = g_inlet_dat_x2(BC_high_wedge0[:,1])
BC_high_U_wedge1_interpolated_g_inlet_dat_x2   = g_inlet_dat_x2(BC_high_wedge1[:,1])
BC_high_U_symmetry_interpolated_g_inlet_dat_x2 = g_inlet_dat_x2(BC_high_symmetry[:,1])

BC_high_k_wedge0_interpolated_g_inlet_dat_x2   = g_inlet_dat_x2_k(BC_high_wedge0[:,1])
BC_high_k_wedge1_interpolated_g_inlet_dat_x2   = g_inlet_dat_x2_k(BC_high_wedge1[:,1])
BC_high_k_symmetry_interpolated_g_inlet_dat_x2 = g_inlet_dat_x2_k(BC_high_symmetry[:,1])

BC_high_omega_wedge0_interpolated_g_inlet_dat_x2   = g_inlet_dat_x2_omega(BC_high_wedge0[:,1])
BC_high_omega_wedge1_interpolated_g_inlet_dat_x2   = g_inlet_dat_x2_omega(BC_high_wedge1[:,1])
BC_high_omega_symmetry_interpolated_g_inlet_dat_x2 = g_inlet_dat_x2_omega(BC_high_symmetry[:,1])

# %%
BC_low_U_symmetry_interpolated_g_inlet_dat_x2_out = np.vstack([BC_low_U_symmetry_interpolated_g_inlet_dat_x2, BC_low_U_symmetry_interpolated_g_inlet_dat_x2 * 0.0, BC_low_U_symmetry_interpolated_g_inlet_dat_x2 * 0.0]).T
BC_low_U_wedge1_interpolated_g_inlet_dat_x2_out   = np.vstack([BC_low_U_wedge1_interpolated_g_inlet_dat_x2, BC_low_U_wedge1_interpolated_g_inlet_dat_x2 * 0.0, BC_low_U_wedge1_interpolated_g_inlet_dat_x2 * 0.0]).T
BC_low_U_wedge0_interpolated_g_inlet_dat_x2_out   = np.vstack([BC_low_U_wedge0_interpolated_g_inlet_dat_x2, BC_low_U_wedge0_interpolated_g_inlet_dat_x2 * 0.0, BC_low_U_wedge0_interpolated_g_inlet_dat_x2 * 0.0]).T

BC_low_k_symmetry_interpolated_g_inlet_dat_x2_out = np.vstack([BC_low_k_symmetry_interpolated_g_inlet_dat_x2, BC_low_k_symmetry_interpolated_g_inlet_dat_x2 * 0.0, BC_low_k_symmetry_interpolated_g_inlet_dat_x2 * 0.0]).T
BC_low_k_wedge1_interpolated_g_inlet_dat_x2_out   = np.vstack([BC_low_k_wedge1_interpolated_g_inlet_dat_x2, BC_low_k_wedge1_interpolated_g_inlet_dat_x2 * 0.0, BC_low_k_wedge1_interpolated_g_inlet_dat_x2 * 0.0]).T
BC_low_k_wedge0_interpolated_g_inlet_dat_x2_out   = np.vstack([BC_low_k_wedge0_interpolated_g_inlet_dat_x2, BC_low_k_wedge0_interpolated_g_inlet_dat_x2 * 0.0, BC_low_k_wedge0_interpolated_g_inlet_dat_x2 * 0.0]).T

BC_low_omega_symmetry_interpolated_g_inlet_dat_x2_out = np.vstack([BC_low_omega_symmetry_interpolated_g_inlet_dat_x2, BC_low_omega_symmetry_interpolated_g_inlet_dat_x2 * 0.0, BC_low_omega_symmetry_interpolated_g_inlet_dat_x2 * 0.0]).T
BC_low_omega_wedge1_interpolated_g_inlet_dat_x2_out   = np.vstack([BC_low_omega_wedge1_interpolated_g_inlet_dat_x2, BC_low_omega_wedge1_interpolated_g_inlet_dat_x2 * 0.0, BC_low_omega_wedge1_interpolated_g_inlet_dat_x2 * 0.0]).T
BC_low_omega_wedge0_interpolated_g_inlet_dat_x2_out   = np.vstack([BC_low_omega_wedge0_interpolated_g_inlet_dat_x2, BC_low_omega_wedge0_interpolated_g_inlet_dat_x2 * 0.0, BC_low_omega_wedge0_interpolated_g_inlet_dat_x2 * 0.0]).T

#BC_low_eps_symmetry_interpolated_g_inlet_dat_x2_out = np.vstack([BC_low_eps_symmetry_interpolated_g_inlet_dat_x2, BC_low_eps_symmetry_interpolated_g_inlet_dat_x2 * 0.0, BC_low_eps_symmetry_interpolated_g_inlet_dat_x2 * 0.0]).T
#BC_low_eps_wedge1_interpolated_g_inlet_dat_x2_out = np.vstack([BC_low_eps_wedge1_interpolated_g_inlet_dat_x2, BC_low_eps_wedge1_interpolated_g_inlet_dat_x2 * 0.0, BC_low_eps_wedge1_interpolated_g_inlet_dat_x2 * 0.0]).T
#BC_low_eps_wedge0_interpolated_g_inlet_dat_x2_out = np.vstack([BC_low_eps_wedge0_interpolated_g_inlet_dat_x2, BC_low_eps_wedge0_interpolated_g_inlet_dat_x2 * 0.0, BC_low_eps_wedge0_interpolated_g_inlet_dat_x2 * 0.0]).T

BC_low_nut_symmetry_interpolated_g_inlet_dat_x2_out = BC_low_k_symmetry_interpolated_g_inlet_dat_x2_out / (BC_low_omega_symmetry_interpolated_g_inlet_dat_x2_out + 0.000001)
BC_low_nut_wedge0_interpolated_g_inlet_dat_x2_out   = BC_low_k_wedge0_interpolated_g_inlet_dat_x2_out / (BC_low_omega_wedge0_interpolated_g_inlet_dat_x2_out + 0.000001)
BC_low_nut_wedge1_interpolated_g_inlet_dat_x2_out   = BC_low_k_wedge1_interpolated_g_inlet_dat_x2_out / (BC_low_omega_wedge1_interpolated_g_inlet_dat_x2_out + 0.000001)

# %%
np.savetxt('BC_low_U_symmetry_interpolated_g_inlet_dat_x2.txt',BC_low_U_symmetry_interpolated_g_inlet_dat_x2_out)
np.savetxt('BC_low_U_wedge1_interpolated_g_inlet_dat_x2_out.txt',BC_low_U_wedge1_interpolated_g_inlet_dat_x2_out)
np.savetxt('BC_low_U_wedge0_interpolated_g_inlet_dat_x2_out.txt',BC_low_U_wedge0_interpolated_g_inlet_dat_x2_out)

np.savetxt('BC_low_k_symmetry_interpolated_g_inlet_dat_x2.txt',BC_low_k_symmetry_interpolated_g_inlet_dat_x2_out)
np.savetxt('BC_low_k_wedge1_interpolated_g_inlet_dat_x2_out.txt',BC_low_k_wedge1_interpolated_g_inlet_dat_x2_out)
np.savetxt('BC_low_k_wedge0_interpolated_g_inlet_dat_x2_out.txt',BC_low_k_wedge0_interpolated_g_inlet_dat_x2_out)

#np.savetxt('BC_low_eps_symmetry_interpolated_g_inlet_dat_x2.txt',BC_low_eps_symmetry_interpolated_g_inlet_dat_x2_out)
#np.savetxt('BC_low_eps_wedge1_interpolated_g_inlet_dat_x2_out.txt',BC_low_eps_wedge1_interpolated_g_inlet_dat_x2_out)
#np.savetxt('BC_low_eps_wedge0_interpolated_g_inlet_dat_x2_out.txt',BC_low_eps_wedge0_interpolated_g_inlet_dat_x2_out)

np.savetxt('BC_low_omega_symmetry_interpolated_g_inlet_dat_x2.txt',BC_low_omega_symmetry_interpolated_g_inlet_dat_x2_out)
np.savetxt('BC_low_omega_wedge1_interpolated_g_inlet_dat_x2_out.txt',BC_low_omega_wedge1_interpolated_g_inlet_dat_x2_out)
np.savetxt('BC_low_omega_wedge0_interpolated_g_inlet_dat_x2_out.txt',BC_low_omega_wedge0_interpolated_g_inlet_dat_x2_out)

np.savetxt('BC_low_nut_symmetry_interpolated_g_inlet_dat_x2.txt',BC_low_nut_symmetry_interpolated_g_inlet_dat_x2_out)
np.savetxt('BC_low_nut_wedge1_interpolated_g_inlet_dat_x2_out.txt',BC_low_nut_wedge1_interpolated_g_inlet_dat_x2_out)
np.savetxt('BC_low_nut_wedge0_interpolated_g_inlet_dat_x2_out.txt',BC_low_nut_wedge0_interpolated_g_inlet_dat_x2_out)

# %%
plt.scatter(inlet_dat[:,0], inlet_dat[:,1], c='b')
plt.scatter(inlet_dat[:,0]*2, inlet_dat[:,1], c='r')
plt.scatter(inlet_dat[:,0]*2, g_inlet_dat_x2(inlet_dat[:,0]*2), c='g', marker='.')
plt.scatter(inlet_dat[:,0], g_inlet_dat(inlet_dat[:,0]), c='y', marker='+')
#plt.scatter(BC_low_wedge0[:,1], BC_low_U_wedge0_interpolated_g_inlet_dat, c='orange')
#plt.scatter(BC_low_wedge1[:,1], BC_low_U_wedge1_interpolated_g_inlet_dat, c='pink')
plt.scatter(BC_low_symmetry[:,1], BC_low_U_symmetry_interpolated_g_inlet_dat, c='brown', marker='x', s=1)
#plt.scatter(BC_high_symmetry[:,1], BC_high_U_symmetry_interpolated_g_inlet_dat, c='gold', marker='x', s=1)
plt.xlabel("Y")
plt.ylabel("U")
plt.show()
plt.close()

# %% [markdown]
# ### U_Exp.dat (missing k, omega, nut) ... not possible to recover other profile variables

# %%
# y,U
U_exp_dat = np.loadtxt('U_Exp.dat')

# %%
g_U_exp_dat = interp1d(np.flip(U_exp_dat[:,0]), U_exp_dat[:,1]) # y, U
g_U_exp_dat_x2 = interp1d(np.flip(U_exp_dat[:,0])*2, U_exp_dat[:,1]) # y(x2), U

# %%
### Interpolate low velocity profiles on inlet.dat data
BC_low_U_wedge0_interpolated_g_U_exp_dat_x2 = g_U_exp_dat_x2(BC_low_wedge0[38:,1]) # a bit shorter ...
BC_low_U_wedge1_interpolated_g_U_exp_dat_x2 = g_U_exp_dat_x2(BC_low_wedge1[38:,1])
BC_low_U_symmetry_interpolated_g_U_exp_dat_x2 = g_U_exp_dat_x2(BC_low_symmetry[38:,1])

# %%
BC_low_U_symmetry_interpolated_g_U_exp_dat_x2.shape
# Out:
# (862,)

# %%
plt.scatter(np.flip(U_exp_dat[:,0]), U_exp_dat[:,1])
plt.scatter(np.flip(U_exp_dat[:,0])*2, g_U_exp_dat_x2(np.flip(U_exp_dat[:,0])*2))
plt.scatter(BC_low_symmetry[38:,1], BC_low_U_symmetry_interpolated_g_U_exp_dat_x2)
plt.xlabel("Y")
plt.ylabel("U")
plt.show()
plt.close()

# %% [markdown]
# ### uinlet02.p

# %%
uinlet02_p = np.loadtxt('uinlet02.p') # y, U
kinlet02_p = np.loadtxt('kinlet02.p') # y, k
epsinlet02_p = np.loadtxt('epsinlet02.p') # y, eps

# %%
uinlet02_p.shape, kinlet02_p.shape, epsinlet02_p.shape
# Out:
# ((158, 2), (158, 2), (158, 2))

# %%
g_uinlet02_p    = interp1d(uinlet02_p[:,0], uinlet02_p[:,1]) # y, U
g_uinlet02_p_x2 = interp1d(uinlet02_p[:,0]*2, uinlet02_p[:,1]) # y(x2), U

g_kinlet02_p    = interp1d(kinlet02_p[:,0], kinlet02_p[:,1]) # y, k
g_kinlet02_p_x2 = interp1d(kinlet02_p[:,0]*2, kinlet02_p[:,1]) # y(x2), k

g_epsinlet02_p    = interp1d(epsinlet02_p[:,0], epsinlet02_p[:,1]) # y, eps
g_epsinlet02_p_x2 = interp1d(epsinlet02_p[:,0]*2, epsinlet02_p[:,1]) # y(x2), eps

# %%
### Interpolate low velocity profiles on inlet.dat data
BC_low_U_wedge0_interpolated_g_uinlet02_p_x2 = g_uinlet02_p_x2(BC_low_wedge0[:,1])
BC_low_U_wedge1_interpolated_g_uinlet02_p_x2 = g_uinlet02_p_x2(BC_low_wedge1[:,1])
BC_low_U_symmetry_interpolated_g_uinlet02_p_x2 = g_uinlet02_p_x2(BC_low_symmetry[:,1])

BC_low_k_wedge0_interpolated_g_kinlet02_p_x2 = g_kinlet02_p_x2(BC_low_wedge0[:,1])
BC_low_k_wedge1_interpolated_g_kinlet02_p_x2 = g_kinlet02_p_x2(BC_low_wedge1[:,1])
BC_low_k_symmetry_interpolated_g_kinlet02_p_x2 = g_kinlet02_p_x2(BC_low_symmetry[:,1])

BC_low_eps_wedge0_interpolated_g_epsinlet02_p_x2 = g_epsinlet02_p_x2(BC_low_wedge0[:,1])
BC_low_eps_wedge1_interpolated_g_epsinlet02_p_x2 = g_epsinlet02_p_x2(BC_low_wedge1[:,1])
BC_low_eps_symmetry_interpolated_g_epsinlet02_p_x2 = g_epsinlet02_p_x2(BC_low_symmetry[:,1])

BC_low_omega_wedge0_interpolated_g_omegainlet02_p_x2   = BC_low_eps_wedge0_interpolated_g_epsinlet02_p_x2 / (0.09 * BC_low_k_wedge0_interpolated_g_kinlet02_p_x2 + 0.000001)
BC_low_omega_wedge1_interpolated_g_omegainlet02_p_x2   = BC_low_eps_wedge1_interpolated_g_epsinlet02_p_x2 / (0.09 * BC_low_k_wedge1_interpolated_g_kinlet02_p_x2 + 0.000001)
BC_low_omega_symmetry_interpolated_g_omegainlet02_p_x2 = BC_low_eps_symmetry_interpolated_g_epsinlet02_p_x2 / (0.09 * BC_low_k_symmetry_interpolated_g_kinlet02_p_x2 + 0.000001)

BC_low_nut_wedge0_interpolated_g_nutinlet02_p_x2   = BC_low_k_wedge0_interpolated_g_kinlet02_p_x2 / BC_low_omega_wedge0_interpolated_g_omegainlet02_p_x2
BC_low_nut_wedge1_interpolated_g_nutinlet02_p_x2   = BC_low_k_wedge1_interpolated_g_kinlet02_p_x2 / BC_low_omega_wedge1_interpolated_g_omegainlet02_p_x2
BC_low_nut_symmetry_interpolated_g_nutinlet02_p_x2 = BC_low_k_symmetry_interpolated_g_kinlet02_p_x2 / BC_low_omega_symmetry_interpolated_g_omegainlet02_p_x2

# %%
BC_low_U_symmetry_interpolated_g_uinlet02_p_x2_out.shape
# Out:
# (900, 3)

# %%
BC_low_U_symmetry_interpolated_g_uinlet02_p_x2_out = np.vstack([BC_low_U_symmetry_interpolated_g_uinlet02_p_x2, BC_low_U_symmetry_interpolated_g_uinlet02_p_x2 * 0.0, BC_low_U_symmetry_interpolated_g_uinlet02_p_x2 * 0.0]).T
BC_low_U_wedge1_interpolated_g_uinlet02_p_x2_out = np.vstack([BC_low_U_wedge1_interpolated_g_uinlet02_p_x2, BC_low_U_wedge1_interpolated_g_uinlet02_p_x2 * 0.0, BC_low_U_wedge1_interpolated_g_uinlet02_p_x2 * 0.0]).T
BC_low_U_wedge0_interpolated_g_uinlet02_p_x2_out = np.vstack([BC_low_U_wedge0_interpolated_g_uinlet02_p_x2, BC_low_U_wedge0_interpolated_g_uinlet02_p_x2 * 0.0, BC_low_U_wedge0_interpolated_g_uinlet02_p_x2 * 0.0]).T

BC_low_k_symmetry_interpolated_g_kinlet02_p_x2_out = np.vstack([BC_low_k_symmetry_interpolated_g_kinlet02_p_x2, BC_low_k_symmetry_interpolated_g_kinlet02_p_x2 * 0.0, BC_low_k_symmetry_interpolated_g_kinlet02_p_x2 * 0.0]).T
BC_low_k_wedge1_interpolated_g_kinlet02_p_x2_out = np.vstack([BC_low_k_wedge1_interpolated_g_kinlet02_p_x2, BC_low_k_wedge1_interpolated_g_kinlet02_p_x2 * 0.0, BC_low_k_wedge1_interpolated_g_kinlet02_p_x2 * 0.0]).T
BC_low_k_wedge0_interpolated_g_kinlet02_p_x2_out = np.vstack([BC_low_k_wedge0_interpolated_g_kinlet02_p_x2, BC_low_k_wedge0_interpolated_g_kinlet02_p_x2 * 0.0, BC_low_k_wedge0_interpolated_g_kinlet02_p_x2 * 0.0]).T

BC_low_eps_symmetry_interpolated_g_epsinlet02_p_x2_out = np.vstack([BC_low_eps_symmetry_interpolated_g_epsinlet02_p_x2, BC_low_eps_symmetry_interpolated_g_epsinlet02_p_x2 * 0.0, BC_low_eps_symmetry_interpolated_g_epsinlet02_p_x2 * 0.0]).T
BC_low_eps_wedge1_interpolated_g_epsinlet02_p_x2_out = np.vstack([BC_low_eps_wedge1_interpolated_g_epsinlet02_p_x2, BC_low_eps_wedge1_interpolated_g_epsinlet02_p_x2 * 0.0, BC_low_eps_wedge1_interpolated_g_epsinlet02_p_x2 * 0.0]).T
BC_low_eps_wedge0_interpolated_g_epsinlet02_p_x2_out = np.vstack([BC_low_eps_wedge0_interpolated_g_epsinlet02_p_x2, BC_low_eps_wedge0_interpolated_g_epsinlet02_p_x2 * 0.0, BC_low_eps_wedge0_interpolated_g_epsinlet02_p_x2 * 0.0]).T

BC_low_omega_symmetry_interpolated_g_omegainlet02_p_x2_out = BC_low_eps_symmetry_interpolated_g_epsinlet02_p_x2_out / (0.09 * BC_low_k_symmetry_interpolated_g_kinlet02_p_x2_out + 0.000001)
BC_low_omega_wedge0_interpolated_g_omegainlet02_p_x2_out = BC_low_eps_wedge0_interpolated_g_epsinlet02_p_x2_out / (0.09 * BC_low_k_wedge0_interpolated_g_kinlet02_p_x2_out + 0.000001)
BC_low_omega_wedge1_interpolated_g_omegainlet02_p_x2_out = BC_low_eps_wedge1_interpolated_g_epsinlet02_p_x2_out / (0.09 * BC_low_k_wedge1_interpolated_g_kinlet02_p_x2_out + 0.000001)

BC_low_nut_symmetry_interpolated_g_nutinlet02_p_x2_out = BC_low_k_symmetry_interpolated_g_kinlet02_p_x2_out / (BC_low_omega_symmetry_interpolated_g_omegainlet02_p_x2_out + 0.000001)
BC_low_nut_wedge0_interpolated_g_nutinlet02_p_x2_out = BC_low_k_wedge0_interpolated_g_kinlet02_p_x2_out / (BC_low_omega_wedge0_interpolated_g_omegainlet02_p_x2_out + 0.000001)
BC_low_nut_wedge1_interpolated_g_nutinlet02_p_x2_out = BC_low_k_wedge1_interpolated_g_kinlet02_p_x2_out / (BC_low_omega_wedge1_interpolated_g_omegainlet02_p_x2_out + 0.000001)

# %%
np.savetxt('BC_low_U_symmetry_interpolated_g_uinlet02_p_x2.txt',BC_low_U_symmetry_interpolated_g_uinlet02_p_x2_out)
np.savetxt('BC_low_U_wedge1_interpolated_g_uinlet02_p_x2_out.txt',BC_low_U_wedge1_interpolated_g_uinlet02_p_x2_out)
np.savetxt('BC_low_U_wedge0_interpolated_g_uinlet02_p_x2_out.txt',BC_low_U_wedge0_interpolated_g_uinlet02_p_x2_out)

np.savetxt('BC_low_k_symmetry_interpolated_g_kinlet02_p_x2.txt',BC_low_k_symmetry_interpolated_g_kinlet02_p_x2_out)
np.savetxt('BC_low_k_wedge1_interpolated_g_kinlet02_p_x2_out.txt',BC_low_k_wedge1_interpolated_g_kinlet02_p_x2_out)
np.savetxt('BC_low_k_wedge0_interpolated_g_kinlet02_p_x2_out.txt',BC_low_k_wedge0_interpolated_g_kinlet02_p_x2_out)

np.savetxt('BC_low_eps_symmetry_interpolated_g_epsinlet02_p_x2.txt',BC_low_eps_symmetry_interpolated_g_epsinlet02_p_x2_out)
np.savetxt('BC_low_eps_wedge1_interpolated_g_epsinlet02_p_x2_out.txt',BC_low_eps_wedge1_interpolated_g_epsinlet02_p_x2_out)
np.savetxt('BC_low_eps_wedge0_interpolated_g_epsinlet02_p_x2_out.txt',BC_low_eps_wedge0_interpolated_g_epsinlet02_p_x2_out)

np.savetxt('BC_low_omega_symmetry_interpolated_g_omegainlet02_p_x2.txt',BC_low_omega_symmetry_interpolated_g_omegainlet02_p_x2_out)
np.savetxt('BC_low_omega_wedge1_interpolated_g_omegainlet02_p_x2_out.txt',BC_low_omega_wedge1_interpolated_g_omegainlet02_p_x2_out)
np.savetxt('BC_low_omega_wedge0_interpolated_g_omegainlet02_p_x2_out.txt',BC_low_omega_wedge0_interpolated_g_omegainlet02_p_x2_out)

np.savetxt('BC_low_nut_symmetry_interpolated_g_nutinlet02_p_x2.txt',BC_low_nut_symmetry_interpolated_g_nutinlet02_p_x2_out)
np.savetxt('BC_low_nut_wedge1_interpolated_g_nutinlet02_p_x2_out.txt',BC_low_nut_wedge1_interpolated_g_nutinlet02_p_x2_out)
np.savetxt('BC_low_nut_wedge0_interpolated_g_nutinlet02_p_x2_out.txt',BC_low_nut_wedge0_interpolated_g_nutinlet02_p_x2_out)

# %%
plt.scatter(uinlet02_p[:,0], uinlet02_p[:,1])
plt.scatter(uinlet02_p[:,0]*2, g_uinlet02_p_x2(uinlet02_p[:,0]*2))
plt.scatter(BC_low_symmetry[:,1], BC_low_U_symmetry_interpolated_g_uinlet02_p_x2)
plt.xlabel("Y")
plt.ylabel("U")
plt.show()
plt.close()

# %%
plt.figure(figsize=(20,15))
plt.plot(inlet_dat[:,0],          inlet_dat[:,1],  label='inlet.dat')
plt.plot(np.flip(U_exp_dat[:,0]), U_exp_dat[:,1],  label='U_exp.dat')
plt.plot(uinlet02_p[:,0],         uinlet02_p[:,1], label='uinlet02.p')
plt.xlabel("Y")
plt.ylabel("U")
plt.grid()
plt.legend()
plt.show()
plt.close()

# %%
#BC_high_wedge0     = np.loadtxt('../BSL_g0_higher_IC/constant/boundaryData.high/inlet/points_wedge0.txt')

# %%
#g = interp1d(BC_high_wedge0[:,1], BC_high_U_wedge0[:,0])
#U_inlet_dat_U_int_HIGH = g(inlet_dat[1:,0])

# %%
#wedge0   = np.loadtxt('../BSL_g0/constant/boundaryData/inlet/points_wedge0.txt') # x,y,z
#wedge1   = np.loadtxt('../BSL_g0/constant/boundaryData/inlet/points_wedge1.txt')
#symmetry = np.loadtxt('../BSL_g0/constant/boundaryData/inlet/points_symmetry.txt')

# %% [markdown]
# #### Interpolate inlet.dat on wedge0, wedge1 and symmetry

# %%
#g = interp1d(inlet_dat[:,0], inlet_dat[:,1], kind='nearest') #, bounds_error=False, kind='linear',fill_value=(inlet_dat[0,1], inlet_dat[-1,1])) # <--- y,U
#U_wedge0_int = g(wedge0[0,1])

# %% [markdown]
# #### Interpolate U_exp.dat on wedge0, wedge1 and symmetry

# %%
#g = interp1d(U_exp_dat[:,0], U_exp_dat[:,1], kind='nearest')
#U_wedge0_int = g(wedge0[:,1])

# %%
#from scipy.interpolate import CubicSpline
#
#xs = inlet_dat[:,0]
#ys = inlet_dat[:,1]
#
#notaknot = CubicSpline(xs, ys, bc_type='not-a-knot')
#natural  = CubicSpline(xs, ys, bc_type='natural')
#clamped  = CubicSpline(xs, ys, bc_type='clamped')
#xnew     = wedge0[:,1] #np.linspace(min(xs) - 4, max(xs) + 4, 101)
#
#splines = [notaknot, natural, clamped]
#titles = ['not-a-knot', 'natural', 'clamped']
#
#fig, axs = plt.subplots(3, 3, figsize=(12, 12))
#or i in [0, 1, 2]:
#    for j, spline, title in zip(range(3), splines, titles):
#        axs[i, j].plot(xs, spline(xs, nu=i),'o')
#        axs[i, j].plot(xnew, spline(xnew, nu=i),'-')
#        axs[i, j].set_title(f'{title}, deriv={i}')
#
#plt.tight_layout()
#plt.show()

# %%
#from scipy.interpolate import InterpolatedUnivariateSpline
#
#spl = InterpolatedUnivariateSpline(inlet_dat[:,0], inlet_dat[:,1])
#plt.plot(inlet_dat[:,0], inlet_dat[:,1], 'ro', ms=5)
#xs = wedge0[:,1]
#plt.plot(xs, spl(xs), 'g', lw=3, alpha=0.7)
#plt.show()
#plt.close()
#spl.get_residual()

# %%
#plt.scatter(inlet_dat[:,0], inlet_dat[:,1])
#plt.scatter(wedge0[:,0], U_wedge0_int)
#plt.show()

# %%
BSL_g0_higher_IC_scale_down_Cx = np.loadtxt('../BSL_g0_higher_IC_scale_down/0/Cx.txt')
BSL_g0_higher_IC_scale_down_Cy = np.loadtxt('../BSL_g0_higher_IC_scale_down/0/Cy.txt')
BSL_g0_higher_IC_scale_down_Cz = np.loadtxt('../BSL_g0_higher_IC_scale_down/0/Cz.txt')
#BSL_g0_higher_IC_scale_down_U  = np.loadtxt('../BSL_g0_higher_IC_scale_down/postProcessing/sampleDict/0/Xmin_U.xy')

# %%
BSL_g0_higher_IC_scale_down_Cy.min(), BSL_g0_higher_IC_scale_down_Cy.max(), BSL_g0_higher_IC_scale_down_Cy.shape
# Out:
# (0.0001107101309, 0.4994410828, (380,))

# %%
BSL_g0_higher_IC_scale_down_U_interpolate_g_inlet_dat  = g_inlet_dat(BSL_g0_higher_IC_scale_down_Cy)
#BSL_g0_higher_IC_scale_down_U_interpolate_g_U_exp_dat  = g_U_exp_dat(BSL_g0_higher_IC_scale_down_Cy)
BSL_g0_higher_IC_scale_down_U_interpolate_g_uinlet02_p = g_uinlet02_p(BSL_g0_higher_IC_scale_down_Cy)

# %%
BSL_g0_higher_IC_scale_down_U_interpolate.shape
# Out:
# (380,)

# %%
BSL_g0_higher_IC_Cx = np.loadtxt('../BSL_g0_higher_IC/0/Cx.txt')
BSL_g0_higher_IC_Cy = np.loadtxt('../BSL_g0_higher_IC/0/Cy.txt')
BSL_g0_higher_IC_Cz = np.loadtxt('../BSL_g0_higher_IC/0/Cz.txt')
#
BSL_g0_higher_IC_Xmin = np.loadtxt('../BSL_g0_higher_IC/postProcessing/sampleDict/0/Xmin_U.xy')

# %%
BSL_g0_higher_IC_Cy.shape, BSL_g0_higher_IC_U.shape, BSL_g0_higher_IC_Xmin.shape
# Out:
# ((380,), (382, 4), (382, 4))

# %%
interpolated_BSL_g0_higher_IC_scale_down_U = g_BC_low_wedge0(BSL_g0_higher_IC_scale_down_Cy[1:]) # y = 0 - 0.5
interpolated_BSL_g0_higher_IC_U =            g_BC_low_wedge0(BSL_g0_higher_IC_Cy[1:])            # y = 0 - 1

# %%
interpolated_BSL_g0_higher_IC_scale_down_U.shape, BSL_g0_higher_IC_scale_down_Cy[1:].shape
interpolated_BSL_g0_higher_IC_U.shape, BSL_g0_higher_IC_Cy[1:].shape
# Out:
# ((379,), (379,))

# %%
BSL_g0_higher_IC_Cy.shape, BSL_g0_higher_IC_Xmin.shape
# Out:
# ((380,), (382, 4))

# %%
plt.figure(figsize=(20,15))
plt.plot(BC_low_wedge0[:,1], BC_low_U_wedge0[:,0], label='OF LOW')
plt.plot(inlet_dat[1:,0], U_inlet_dat_U_int_LOW, label='inlet.dat LOW int')
plt.plot(U_exp_dat[:,0], U_exp_int_LOW, label='U_exp_dat LOW int')
plt.plot(BC_high_wedge0[:,1], BC_high_U_wedge0[:,0], label='OF HIGH')
plt.plot(inlet_dat[1:,0], U_inlet_dat_U_int_HIGH, label='inlet.dat HIGH int')
plt.scatter(BSL_g0_higher_IC_scale_down_Cy[1:], interpolated_BSL_g0_higher_IC_scale_down_U, label='interp. high IC scaled down')
plt.scatter(BSL_g0_higher_IC_Cy[1:], interpolated_BSL_g0_higher_IC_U, label='interp. high IC')
#
plt.plot(inlet_dat[:,0]*2, inlet_dat[:,1]*2, c='k', linewidth=5,                                   label='inlet.dat (x2)')
#
plt.scatter(BSL_g0_higher_IC_Xmin[:,0], BSL_g0_higher_IC_Xmin[:,1], label='interp. high IC')
plt.scatter(BSL_g0_higher_IC_Cy, BSL_g0_higher_IC_Xmin[:380,1], label='interp. high IC')
plt.scatter(BSL_g0_higher_IC_scale_down_Cy, BSL_g0_higher_IC_scale_down_U_interpolate_g_inlet_dat)
plt.scatter(BSL_g0_higher_IC_scale_down_Cy, BSL_g0_higher_IC_scale_down_U_interpolate_g_uinlet02_p)
#
plt.xlabel("Y")
plt.ylabel("U")
plt.grid()
plt.legend()
plt.show()
plt.close()
